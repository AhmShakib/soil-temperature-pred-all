# %%
import pandas as pd 
import numpy as np 

df=pd.read_csv("ReadySoilDataset_Final.csv")
df.head()
# Out:
#    Region  Year  Month  SoilTemperature-10  SoilTemperature-30  \
# 0       0  2001      1               17.89               19.85
# 1       0  2001      2               21.95               22.76
# 2       0  2001      3               26.32               27.46
# 3       0  2001      4               30.51               31.25
# 4       0  2001      5               30.05               31.21
#
#    SoilTemperature-50  Rainfall  Temperature  Min Temperature  \
# 0               19.94       0.0        17.08            10.13
# 1               22.13      64.0        21.82            14.94
# 2               26.37      21.0        25.91            19.05
# 3               29.97      51.0        28.98            23.57
# 4               30.41     244.0        28.28            23.70
#
#    Max Temperature  Humidity  Sunshine  Wind Speed  Surface Pressure  \
# 0            25.71     80.48      8.92        2.24         101281.92
# 1            29.49     78.07      8.60        2.06         101059.03
# ...

# %%
# Out:
# Epoch 0, Loss: 0.20432
# Epoch 50, Loss: 6642035217107337882251997970649513279720831703358755357822625853977805368154033760501760.00000
# Epoch 100, Loss: 9541018293673784882883764917988001940391898058199914039908077662977087185323962401557774088317832938360340630698331182923288411893931679132851580497645286821753296433218322432.00000
# Epoch 150, Loss: .00000
# Epoch 200, Loss: inf
# Epoch 250, Loss: nan
# Epoch 300, Loss: nan
# Epoch 350, Loss: nan
# Epoch 400, Loss: nan
# Epoch 450, Loss: nan
# ⚠️ NaN detected in predictions or test labels.
# C:\Users\HP Laptop 15\tfenv\lib\site-packages\numpy\core\_methods.py:118: RuntimeWarning: overflow encountered in reduce
# ...
