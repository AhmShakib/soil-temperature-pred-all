# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

import math
# Load data
df = pd.read_csv("Final Dataset.csv")
df = df[df['Region'].isin([2,4,5,7])].reset_index(drop=True)
df.tail(10)
# Out:
#       Region  Year  Month  SoilTemperature-10  SoilTemperature-30  \
# 1045       7  2022      3               27.59               26.70
# 1046       7  2022      4               30.10               29.31
# 1047       7  2022      5               29.86               29.48
# 1048       7  2022      6               30.45               30.02
# 1049       7  2022      7               32.03               31.60
# 1050       7  2022      8               31.46               31.10
# 1051       7  2022      9               30.54               30.39
# 1052       7  2022     10               28.42               28.60
# 1053       7  2022     11               25.09               25.50
# 1054       7  2022     12               21.63               21.92
#
#       SoilTemperature-50  Rainfall  Temperature  Min Temperature  \
# 1045               24.56       0.0        27.00            20.57
# 1046               27.17     101.0        29.60            25.00
# ...

# %%
df.drop('SoilTemp30_SMA',axis=1,inplace=True)

# %%
df = df.sort_values(by=['Year', 'Month']).reset_index(drop=True)
df['Solar Radiation Lag1'] = df['Solar Radiation'].shift(1)
df.dropna(inplace=True)

features = df[['Year', 'Month', 'Temperature', 'Min Temperature',
               'Max Temperature', 'Wind Speed', 'Sunshine', 'Humidity', 
               'Rainfall', 'Surface Pressure', 'Solar Radiation Lag1']]
target = df['SoilTemperature-50']

X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.20, random_state=2
)

# %%
# Required libraries
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Define models in a dictionary
models = {
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=42),
    'LightGBM': LGBMRegressor(n_estimators=100, random_state=42),
    'XGBoost': XGBRegressor(n_estimators=100, random_state=42)
}


results = {}


for name, model in models.items():
    model.fit(X_train, y_train)                         
    y_pred = model.predict(X_test)                       
    rmse = (mean_squared_error(y_test, y_pred))**0.5 
    r2 = r2_score(y_test, y_pred)                        
    results[name] = {'RMSE': rmse, 'R²': r2}             


for name, metrics in results.items():
    print(f"{name}:")
    print(f"  RMSE: {metrics['RMSE']:.4f}")
    print(f"  R²:   {metrics['R²']:.4f}")
    print("-" * 30)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000230 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2169
# [LightGBM] [Info] Number of data points in the train set: 843, number of used features: 11
# [LightGBM] [Info] Start training from score 26.754152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Random Forest:
#   RMSE: 1.2575
#   R²:   0.8932
# ------------------------------
# Gradient Boosting:
#   RMSE: 1.2263
#   R²:   0.8984
# ------------------------------
# LightGBM:
#   RMSE: 1.2812
#   R²:   0.8891
# ------------------------------
# XGBoost:
#   RMSE: 1.3598
#   R²:   0.8751
# ------------------------------

# %%
# Define hyperparameters to search over
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]
}


rf_model = RandomForestRegressor(random_state=42)


grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid_rf, cv=5,
                              scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
grid_search_rf.fit(X_train, y_train)

# Get the best hyperparameters
best_params_rf = grid_search_rf.best_params_
best_rf_model = grid_search_rf.best_estimator_

# Train the model with the best hyperparameters
best_rf_model.fit(X_train, y_train)

# Evaluate the model's performance
y_pred_rf = best_rf_model.predict(X_test)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# Show results
print("Best Hyperparameters (Random Forest):", best_params_rf)
print("Mean Squared Error (Random Forest):", mse_rf)
print("R-squared (Random Forest):", r2_rf)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# C:\Users\HP Laptop 15\tfenv\lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 810 fits failed out of a total of 2430.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 370 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP Laptop 15\tfenv\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HP Laptop 15\tfenv\lib\site-packages\sklearn\base.py", line 1356, in wrapper
#     estimator._validate_params()
# ...

# %% [markdown]
#  Best Hyperparameters (Random Forest): {'bootstrap': False, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Mean Squared Error (Random Forest): 1.542605001588942
#  R-squared (Random Forest): 0.8957921807489174

# %%
pip install lime
# Out:
# ...
#
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283860 sha256=675d83405b71cfd53c88b071249e398b32a67ae064323cdcead6559ccd922913
#   Stored in directory: c:\users\hp laptop 15\appdata\local\pip\cache\wheels\fd\a2\af\9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\HP Laptop 15\tfenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import shap
shap.initjs()
best_rf_model.fit(X_test, y_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
explainer = shap.TreeExplainer(best_rf_model)

# Calculate SHAP values for the entire test set
shap_values = explainer.shap_values(X_test)

# Plot the summary plot for the SHAP values
shap.summary_plot(shap_values, X_test)

# %%
# plot the SHAP values for the 10th observation 

shap.initjs()
shap.force_plot(explainer.expected_value,shap_values[10,:], X_test.iloc[10,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
feature_names=['Year', 'Month', 'Temperature', 'Min Temperature',
               'Max Temperature', 'Wind Speed', 'Sunshine', 'Humidity', 
               'Rainfall', 'Surface Pressure', 'Solar Radiation Lag1']
shap.summary_plot(shap_values, max_display=15, show=False, plot_type='bar', feature_names=feature_names)

# %%
X=df[['Month', 'Temperature', 'Min Temperature',
               'Max Temperature', 
               'Rainfall', 'Surface Pressure']]
y=df['SoilTemperature-50']
# Split the data into training and testing sets
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.2, random_state=2)


best_rf_model.fit(X_tr, y_tr)

# Make predictions on the test data
y_pr = best_rf_model.predict(X_te)

# Evaluate the model
msee = mean_squared_error(y_te, y_pr)
rr2 = r2_score(y_te, y_pr)

print("Mean Squared Error:", msee)
print("R-squared:", rr2)
# Out:
# Mean Squared Error: 1.197362464612115
# R-squared: 0.9311892940369859

# %%
print("Mean Squared Error (Random Forest):", mse_rf)
print("R-squared (Random Forest):", r2_rf)
# Out:
# Mean Squared Error (Random Forest): 1.542605001588942
# R-squared (Random Forest): 0.8957921807489174

# %%
df.columns
# Out:
# Index(['Region', 'Year', 'Month', 'SoilTemperature-10', 'SoilTemperature-30',
#        'SoilTemperature-50', 'Rainfall', 'Temperature', 'Min Temperature',
#        'Max Temperature', 'Humidity', 'Sunshine', 'Wind Speed',
#        'Surface Pressure', 'Solar Radiation', 'SoilTemp30_SMA'],
#       dtype='object')

# %%
# Plot actual vs predicted
plt.figure(figsize=(10, 5))
plt.plot(y_test.values[:100], label='Actual', marker='o')
plt.plot(y_pred[:100], label='Predicted', marker='x')
plt.title('Actual vs Predicted Soil Temperature at 50cm Depth')
plt.xlabel('Sample Index')
plt.ylabel('SoilTemperature-50')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

#Actual va Predicted Using Shap selected features
plt.figure(figsize=(10, 5))
plt.plot(y_te.values[:100], label='Actual', marker='o')
plt.plot(y_pr[:100], label='Predicted', marker='x')
plt.title('Actual vs Predicted Soil Temperature at 50cm Depth')
plt.xlabel('Sample Index')
plt.ylabel('SoilTemperature-50')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
explainer   = shap.TreeExplainer(best_rf_model)          
shap_values = explainer(X_te.iloc[0:1])     
shap.plots.waterfall(shap_values[0])        

explainer2   = shap.TreeExplainer(best_rf_model)          
shap_values2 = explainer2(X_test.iloc[0:1])     
shap.plots.waterfall(shap_values2[0])
